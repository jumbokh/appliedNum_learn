# %%
from power_B import *

# %%
A = np.array([[40.5,10.5,-21.0,21.0],[10.5, 20.5, -5.0, 5.0],[-21.0, -5.0, 37.0, -1.0],[21.0, 5.0, -1.0, 37.0]])
z = [[1.0],[1.0],[1.0],[1.0]]

# %%
np.set_printoptions(precision=5)
[eigs,vecs] = power_B(A,z,16,0.0001)
print('eigs: ',eigs)
for x in vecs.T:
    print(x,end='')
print()
# Out:
# iter       w1    r  z(x)
# 1 [62.] 27.090638706296474 [[0.8226 0.5    0.1613 1.    ]]
# ===============================================
# 2 [56.6129] 24.217358194211986 [[ 0.9923  0.4077 -0.2615  1.    ]]
# ===============================================
# 3 [70.9615] 9.450017377335088 [[ 1.      0.3535 -0.4728  0.8475]]
# ===============================================
# 4 [71.9385] 4.774350399891018 [[ 1.      0.3385 -0.5715  0.7589]]
# ===============================================
# 5 [71.9923] 2.3871292808706555 [[ 1.      0.3346 -0.6194  0.7132]]
# ===============================================
# 6 [71.999] 1.1933549903494673 [[ 1.      0.3337 -0.6431  0.69  ]]
# ===============================================
# 7 [71.9999] 0.5966374446612831 [[ 1.      0.3334 -0.6549  0.6784]]
# ===============================================
# 8 [72.] 0.2983128166467088 [[ 1.      0.3334 -0.6608  0.6725]]
# ===============================================
# 9 [72.] 0.14915561283678708 [[ 1.      0.3333 -0.6637  0.6696]]
# ===============================================
# 10 [72.] 0.07457770336948963 [[ 1.      0.3333 -0.6652  0.6681]]
# ===============================================
# 11 [72.] 0.03728883857678053 [[ 1.      0.3333 -0.6659  0.6674]]
# ===============================================
# 12 [72.] 0.018644417635679984 [[ 1.      0.3333 -0.6663  0.667 ]]
# ===============================================
# 13 [72.] 0.009322208610358844 [[ 1.      0.3333 -0.6665  0.6668]]
# ===============================================
# 14 [72.] 0.0046611042791937524 [[ 1.      0.3333 -0.6666  0.6668]]
# ===============================================
# 15 [72.] 0.0023305521363436443 [[ 1.      0.3333 -0.6666  0.6667]]
# ===============================================
# 16 [72.] 0.001165276067764854 [[ 1.      0.3333 -0.6666  0.6667]]
# ===============================================
# eigs:  [72.]
# [ 1.      0.3333 -0.6666  0.6667]
