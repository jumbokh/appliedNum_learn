# %%
from QR_eig_G import *
import numpy as np
import scipy.linalg as ALG

# %%
A = np.array([[5,4,1,1],[4,5,1,1],[1,1,4,2],[1,1,2,4]])

# %%
H = ALG.hessenberg(A)
np.set_printoptions(precision=4, suppress=True)
eig = QR_eig_G(H,5,0.001)
print(eig)
# Out:
# K:  1
#   9.6047,  -1.4963,   0.0000,   0.0000,
#  -1.4963,   3.7867,   2.0160,  -0.0000,
#   0.0000,   2.0160,   2.6087,  -0.0000,
#   0.0000,  -0.0000,  -0.0000,   2.0000,
#
# K:  2
#   9.9220,  -0.6233,   0.0000,   0.0000,
#  -0.6233,   4.9763,   0.6326,  -0.0000,
#   0.0000,   0.6326,   1.1018,  -0.0000,
#   0.0000,   0.0000,  -0.0000,   2.0000,
#
# K:  3
#   9.9805,  -0.3114,   0.0000,   0.0000,
#  -0.3114,   5.0153,   0.1289,  -0.0000,
#   0.0000,   0.1289,   1.0042,  -0.0000,
#   0.0000,   0.0000,  -0.0000,   2.0000,
#
# K:  4
#   9.9951,  -0.1561,   0.0000,   0.0000,
#  -0.1561,   5.0047,   0.0258,  -0.0000,
#   0.0000,   0.0258,   1.0002,  -0.0000,
#   0.0000,   0.0000,  -0.0000,   2.0000,
#
# K:  5
#   9.9988,  -0.0781,   0.0000,   0.0000,
#  -0.0781,   5.0012,   0.0052,  -0.0000,
#   0.0000,   0.0052,   1.0000,  -0.0000,
#   0.0000,   0.0000,  -0.0000,   2.0000,
#
# [9.9988 5.0012 1.     2.    ]

# %%
B = np.array([[15,-2,-2,-1],[10,6,-4,-2],[10,4,-1,-3],[10,4,-2,-2]])
H1 = ALG.hessenberg(B)
print(H1)
# Out:
# [[ 15.       2.8868   0.0424   0.8154]
#  [-17.3205  -0.      -8.3043   5.3888]
#  [  0.       0.       2.4946   0.7622]
#  [  0.       0.      -0.9699   0.5054]]

# %%
eig1 = QR_eig_G(H1,20,0.001)
print(eig1)
# Out:
# K:  1
#  13.5714,  18.5577,   7.1594,  -1.0144,
#  -1.6496,   1.4286,  -6.5387,   1.9042,
#  -0.0000,   0.0000,   2.3035,   1.4613,
#  -0.0000,  -0.0000,  -0.2708,   0.6965,
#
# K:  2
#  11.3694,  19.7660,   7.9864,  -0.3065,
#  -0.4413,   3.6306,  -5.7950,   1.0989,
#   0.0000,   0.0000,   2.1436,   1.6314,
#   0.0000,  -0.0000,  -0.1007,   0.8564,
#
# K:  3
#  10.6089,  20.0368,   8.2125,   0.0364,
#  -0.1704,   4.3911,  -5.5258,   0.8278,
#   0.0000,   0.0000,   2.0690,   1.6883,
#   0.0000,  -0.0000,  -0.0437,   0.9310,
#
# K:  4
#  10.2882,  20.1316,   8.2979,   0.1985,
#  -0.0757,   4.7118,  -5.4095,   0.7142,
#   0.0000,   0.0000,   2.0338,   1.7116,
#   0.0000,  -0.0000,  -0.0204,   0.9662,
#
# K:  5
#  10.1403,  20.1715,   8.3351,   0.2769,
#  -0.0358,   4.8597,  -5.3552,   0.6619,
#   0.0000,   0.0000,   2.0167,   1.7222,
#   0.0000,  -0.0000,  -0.0099,   0.9833,
#
# K:  6
#  10.0692,  20.1899,   8.3525,   0.3155,
#  -0.0174,   4.9308,  -5.3290,   0.6368,
#   0.0000,   0.0000,   2.0083,   1.7272,
#   0.0000,  -0.0000,  -0.0049,   0.9917,
#
# K:  7
#  10.0344,  20.1987,   8.3609,   0.3346,
#  -0.0086,   4.9656,  -5.3161,   0.6245,
#   0.0000,   0.0000,   2.0041,   1.7296,
#   0.0000,  -0.0000,  -0.0024,   0.9959,
#
# K:  8
#  10.0171,  20.2030,   8.3650,   0.3441,
#  -0.0043,   4.9829,  -5.3097,   0.6184,
#   0.0000,   0.0000,   2.0021,   1.7309,
#   0.0000,  -0.0000,  -0.0012,   0.9979,
#
# K:  9
#  10.0086,  20.2051,   8.3671,   0.3488,
#  -0.0021,   4.9914,  -5.3065,   0.6154,
#  -0.0000,   0.0000,   2.0010,   1.7315,
#  -0.0000,  -0.0000,  -0.0006,   0.9990,
#
# K:  10
#  10.0043,  20.2062,   8.3681,   0.3512,
#  -0.0011,   4.9957,  -5.3049,   0.6139,
#  -0.0000,   0.0000,   2.0005,   1.7318,
#  -0.0000,  -0.0000,  -0.0003,   0.9995,
#
# K:  11
#  10.0021,  20.2067,   8.3686,   0.3524,
#  -0.0005,   4.9979,  -5.3041,   0.6131,
#  -0.0000,   0.0000,   2.0003,   1.7319,
#  -0.0000,  -0.0000,  -0.0001,   0.9997,
#
# K:  12
#  10.0011,  20.2070,   8.3688,   0.3530,
#  -0.0003,   4.9989,  -5.3037,   0.6127,
#  -0.0000,   0.0000,   2.0001,   1.7320,
#  -0.0000,  -0.0000,  -0.0001,   0.9999,
#
# K:  13
#  10.0005,  20.2071,   8.3690,   0.3533,
#  -0.0001,   4.9995,  -5.3035,   0.6126,
#  -0.0000,   0.0000,   2.0001,   1.7320,
#  -0.0000,  -0.0000,  -0.0000,   0.9999,
#
# K:  14
#  10.0003,  20.2072,   8.3690,   0.3534,
#  -0.0001,   4.9997,  -5.3034,   0.6125,
#   0.0000,   0.0000,   2.0000,   1.7320,
#   0.0000,  -0.0000,  -0.0000,   1.0000,
#
# K:  15
#  10.0001,  20.2072,   8.3691,   0.3535,
#  -0.0000,   4.9999,  -5.3034,   0.6124,
#   0.0000,   0.0000,   2.0000,   1.7320,
#   0.0000,  -0.0000,  -0.0000,   1.0000,
#
# K:  16
#  10.0001,  20.2072,   8.3691,   0.3535,
#  -0.0000,   4.9999,  -5.3033,   0.6124,
#   0.0000,   0.0000,   2.0000,   1.7320,
#   0.0000,  -0.0000,  -0.0000,   1.0000,
#
# K:  17
#  10.0000,  20.2073,   8.3691,   0.3535,
#  -0.0000,   5.0000,  -5.3033,   0.6124,
#   0.0000,   0.0000,   2.0000,   1.7320,
#   0.0000,  -0.0000,  -0.0000,   1.0000,
#
# K:  18
#  10.0000,  20.2073,   8.3691,   0.3535,
#  -0.0000,   5.0000,  -5.3033,   0.6124,
#   0.0000,   0.0000,   2.0000,   1.7320,
#   0.0000,  -0.0000,  -0.0000,   1.0000,
#
# K:  19
#  10.0000,  20.2073,   8.3691,   0.3535,
#  -0.0000,   5.0000,  -5.3033,   0.6124,
#   0.0000,   0.0000,   2.0000,   1.7321,
#   0.0000,  -0.0000,  -0.0000,   1.0000,
#
# K:  20
#  10.0000,  20.2073,   8.3691,   0.3536,
#  -0.0000,   5.0000,  -5.3033,   0.6124,
#  -0.0000,   0.0000,   2.0000,   1.7321,
#  -0.0000,  -0.0000,  -0.0000,   1.0000,
#
# [10.  5.  2.  1.]
