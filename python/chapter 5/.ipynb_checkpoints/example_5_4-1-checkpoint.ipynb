# %%
from power_B import *
import numpy as np

# %%
A = np.array([[4.0,2.0/3.0,-4.0/3.0,4.0/3.0],[2.0/3.0, 4.0, 0.0, 0.0],[-4.0/3.0, 0.0, 6.0, 2.0],[4.0/3.0, 0.0, 2.0, 6.0]])
w = np.array([[1.0],[1.0],[1.0],[1.0]])
print(A)
# Out:
# [[ 4.      0.6667 -1.3333  1.3333]
#  [ 0.6667  4.      0.      0.    ]
#  [-1.3333  0.      6.      2.    ]
#  [ 1.3333  0.      2.      6.    ]]

# %%
np.set_printoptions(precision=5)
[eigs,vecs] = power_B(A,w,20,0.001)
print('eigs: ',eigs)
print('vecs: ',end='')
for x in vecs.T:
    print(x,end='')
print()
# Out:
# iter       w1    r  z(x)
# 1 [9.3333] 3.447697973313895 [[0.5    0.5    0.7143 1.    ]]
# ===============================================
# 2 [8.0952] 1.2611807708084577 [[0.3353 0.2882 0.6941 1.    ]]
# ===============================================
# 3 [7.8353] 0.770301914814893 [[0.2477 0.1757 0.7297 1.    ]]
# ===============================================
# 4 [7.7898] 0.5779630377271144 [[0.1885 0.1114 0.7764 1.    ]]
# ===============================================
# 5 [7.8042] 0.45725131790851514 [[0.1443 0.0732 0.821  1.    ]]
# ===============================================
# 6 [7.8344] 0.36340017232831606 [[0.1104 0.0497 0.8595 1.    ]]
# ===============================================
# 7 [7.8661] 0.28650484239214064 [[0.0842 0.0346 0.8911 1.    ]]
# ===============================================
# 8 [7.8945] 0.22361374120138022 [[0.064  0.0246 0.9164 1.    ]]
# ===============================================
# 9 [7.9181] 0.17294175445285076 [[0.0485 0.0178 0.9362 1.    ]]
# ===============================================
# 10 [7.9371] 0.13275790834186965 [[0.0366 0.0131 0.9516 1.    ]]
# ===============================================
# 11 [7.952] 0.10131892123215332 [[0.0276 0.0096 0.9634 1.    ]]
# ===============================================
# 12 [7.9636] 0.0769824698434741 [[0.0208 0.0072 0.9723 1.    ]]
# ===============================================
# 13 [7.9724] 0.05829650464807143 [[0.0157 0.0053 0.9792 1.    ]]
# ===============================================
# 14 [7.9792] 0.04403629165570284 [[0.0118 0.004  0.9843 1.    ]]
# ===============================================
# 15 [7.9843] 0.0332028071237854 [[0.0089 0.003  0.9882 1.    ]]
# ===============================================
# 16 [7.9882] 0.025000164075645058 [[0.0067 0.0022 0.9911 1.    ]]
# ===============================================
# 17 [7.9911] 0.018804840380174808 [[0.005  0.0017 0.9933 1.    ]]
# ===============================================
# 18 [7.9933] 0.0141341542569642 [[0.0037 0.0013 0.995  1.    ]]
# ===============================================
# 19 [7.995] 0.010617644543889526 [[0.0028 0.0009 0.9962 1.    ]]
# ===============================================
# 20 [7.9963] 0.00797273625024498 [[0.0021 0.0007 0.9972 1.    ]]
# ===============================================
# eigs:  [7.9963]
# vecs: [0.0021 0.0007 0.9972 1.    ]

# %%
def rayleigh(A,w,n,tol=0.001):
    np.set_printoptions(precision=4)
    np.set_printoptions(suppress=True)
    print('iter     m       r     z(x)')
    for i in range(n):
          # power_B
          #w0 = np.dot(A,w)
          #m0 = max(abs(w0))
          # Rayleigh
          z = w/np.linalg.norm(w)
          w = np.dot(A,z)
          m = np.dot(z.T,w)
          r = np.linalg.norm(m*z-w)
          rr = str(r)
          print('{:<5}'.format(str(i+1)),m[0],'{:.5}'.format(rr),z.T)
          print('===============================================')
          if( r < tol):
              print('Power Method has coverged')
              break
    return [m[0],z]

# %%
[eigs,vecs] = rayleigh(A,w,10,0.001)
print('eigs: ',eigs)
print('vecs: ',end='')
for x in vecs.T:
    print(x,end='')
print()
# Out:
# iter     m       r     z(x)
# 1     [6.3333] 1.914 [[0.5 0.5 0.5 0.5]]
# ===============================================
# 2     [7.2792] 1.301 [[0.3527 0.3527 0.5038 0.7053]]
# ===============================================
# 3     [7.6621] 0.872 [[0.2589 0.2226 0.536  0.7721]]
# ===============================================
# 4     [7.8286] 0.604 [[0.1944 0.1378 0.5725 0.7845]]
# ===============================================
# 5     [7.9083] 0.433 [[0.1467 0.0867 0.6043 0.7783]]
# ===============================================
# 6     [7.9495] 0.319 [[0.1107 0.0561 0.6296 0.7669]]
# ===============================================
# 7     [7.9718] 0.237 [[0.0834 0.0375 0.6491 0.7552]]
# ===============================================
# 8     [7.9842] 0.177 [[0.0627 0.0258 0.6638 0.7449]]
# ===============================================
# 9     [7.9911] 0.133 [[0.0471 0.0181 0.6748 0.7363]]
# ===============================================
# 10    [7.995] 0.099 [[0.0354 0.013  0.683  0.7295]]
# ===============================================
# eigs:  [7.995]
# vecs: [0.0354 0.013  0.683  0.7295]
