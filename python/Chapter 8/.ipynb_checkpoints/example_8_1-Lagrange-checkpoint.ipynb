# %%
import numpy as np

# %%
from lagrange import *
import math

# %%
xData = np.array([-2,0.2,2,0.6])
yData = np.array([1.0,1.22140,1.49182,1.82212])
c = LagrangeCoef(xData,yData)

plotp(xData,yData,-2.0,2.1,0.5,c)  // x>-2.0, x<2.1, step = 0.5

# %%
r = 1.64881 -1.64872 
print('{:8.5f}'.format(r))
