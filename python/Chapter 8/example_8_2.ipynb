# %%
import numpy as np
from lagrange import *

# %%
xData = np.array([0.0,0.50,1.0,1.50,2.0])
yData = np.array([0.0,0.19,0.26,0.29,0.31])

# %%
c = LagrangeCoef(xData,yData)
plotp(xData,yData,-0.1,2.0,0.05,c)

# %%
xall = np.array([0.0,0.1,0.4,0.5,0.6,0.9,1.0,1.1,1.4,1.5,1.6,1.9,2.0])
yall = np.array([0.0,0.06,0.17,0.19,0.21,0.25,0.26,0.27,0.29,0.29,0.30,0.31,0.31])

# %%
c1 = LagrangeCoef(xall,yall)
plotp(xall,yall,0.0,2.1,0.05,c1)
